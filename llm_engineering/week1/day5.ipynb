# %% [markdown]
# # A full business solution
#
# ## Now we will take our project from Day 1 to the next level
#
# ### BUSINESS CHALLENGE:
#
# Create a product that builds a Brochure for a company to be used for prospective clients, investors and potential recruits.
#
# We will be provided a company name and their primary website.
#
# See the end of this notebook for examples of real-world business applications.
#
# And remember: I'm always available if you have problems or ideas! Please do reach out.

# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# Initialize and constants

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gpt-4o-mini'
openai = OpenAI()
# Out:
# API key looks good so far

# %%
# A class to represent a Webpage

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    A utility class to represent a Website that we have scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# %%
ed = Website("https://edwarddonner.com")
ed.links
# Out:
# ['https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'https://edwarddonner.com/',
#  'https://news.ycombinator.com',
#  'https://nebula.io/?utm_source=ed&utm_medium=referral',
#  'https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html',
#  'https://patents.google.com/patent/US20210049536A1/',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/',
#  'https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/',
#  'https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/',
#  'https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'mailto:hello@mygroovydomain.com',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://twitter.com/edwarddonner',
#  'https://www.facebook.com/edward.donner.52']

# %% [markdown]
# ## First step: Have GPT-4o-mini figure out which links are relevant
#
# ### Use a call to gpt-4o-mini to read the links on a webpage, and respond in structured JSON.
# It should decide which links are relevant, and replace relative links such as "/about" with "https://company.com/about".
# We will use "one shot prompting" in which we provide an example of how it should respond in the prompt.
#
# This is an excellent use case for an LLM, because it requires nuanced understanding. Imagine trying to code this without LLMs by parsing and analyzing the webpage - it would be very hard!
#
# Sidenote: there is a more advanced technique called "Structured Outputs" in which we require the model to respond according to a spec. We cover this technique in Week 8 during our autonomous Agentic AI project.

# %%
link_system_prompt = "You are provided with a list of links found on a webpage. \
You are able to decide which of the links would be most relevant to include in a brochure about the company, \
such as links to an About page, or a Company page, or Careers/Jobs pages.\n"
link_system_prompt += "You should respond in JSON as in this example:"
link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page", "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
print(link_system_prompt)
# Out:
# You are provided with a list of links found on a webpage. You are able to decide which of the links would be most relevant to include in a brochure about the company, such as links to an About page, or a Company page, or Careers/Jobs pages.
# You should respond in JSON as in this example:
# {
#     "links": [
#         {"type": "about page", "url": "https://full.url/goes/here/about"},
#         {"type": "careers page", "url": "https://another.full.url/careers"}
#     ]
# }

# %%
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. \
Do not include Terms of Service, Privacy, email links.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
print(get_links_user_prompt(ed))
# Out:
# Here is the list of links on the website of https://edwarddonner.com - please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. Do not include Terms of Service, Privacy, email links.
# Links (some might be relative links):
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# https://edwarddonner.com/
# https://news.ycombinator.com
# https://nebula.io/?utm_source=ed&utm_medium=referral
# https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html
# https://patents.google.com/patent/US20210049536A1/
# https://www.linkedin.com/in/eddonner/
# https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/
# https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/
# https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/
# https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# mailto:hello@mygroovydomain.com
# https://www.linkedin.com/in/eddonner/
# https://twitter.com/edwarddonner
# https://www.facebook.com/edward.donner.52

# %%
def get_links(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(website)}
      ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    return json.loads(result)

# %%
# Anthropic has made their site harder to scrape, so I'm using HuggingFace..

huggingface = Website("https://huggingface.co")
huggingface.links
# Out:
# ['/',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/docs',
#  '/enterprise',
#  '/pricing',
#  '/login',
#  '/join',
#  'inference/get-started',
#  '/spaces',
#  '/models',
#  '/zai-org/GLM-4.5',
#  '/Qwen/Qwen3-Coder-480B-A35B-Instruct',
#  '/tencent/HunyuanWorld-1',
#  '/bosonai/higgs-audio-v2-generation-3B-base',
#  '/Qwen/Qwen3-235B-A22B-Thinking-2507',
#  '/models',
#  '/spaces/enzostvs/deepsite',
#  '/spaces/zumjoy/Multi-Style_Video-to-Anime_Generator',
#  '/spaces/smola/higgs_audio_v2',
#  '/spaces/Qwen/Qwen3-Coder-WebDev',
#  '/spaces/black-forest-labs/FLUX.1-Kontext-Dev',
#  '/spaces',
#  '/datasets/fka/awesome-chatgpt-prompts',
#  '/datasets/NousResearch/Hermes-3-Dataset',
#  '/datasets/interstellarninja/hermes_reasoning_tool_use',
#  '/datasets/MegaScience/MegaScience',
#  '/datasets/microsoft/rStar-Coder',
#  '/datasets',
#  '/join',
#  '/pricing#endpoints',
#  '/pricing#spaces',
#  '/pricing',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/allenai',
#  '/facebook',
#  '/amazon',
#  '/google',
#  '/Intel',
#  '/microsoft',
#  '/grammarly',
#  '/Writer',
#  '/docs/transformers',
#  '/docs/diffusers',
#  '/docs/safetensors',
#  '/docs/huggingface_hub',
#  '/docs/tokenizers',
#  '/docs/trl',
#  '/docs/transformers.js',
#  '/docs/smolagents',
#  '/docs/peft',
#  '/docs/datasets',
#  '/docs/text-generation-inference',
#  '/docs/accelerate',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/changelog',
#  'https://endpoints.huggingface.co',
#  '/chat',
#  '/huggingface',
#  '/brand',
#  '/terms-of-service',
#  '/privacy',
#  'https://apply.workable.com/huggingface/',
#  'mailto:press@huggingface.co',
#  '/learn',
#  '/docs',
#  '/blog',
#  'https://discuss.huggingface.co',
#  'https://status.huggingface.co/',
#  'https://github.com/huggingface',
#  'https://twitter.com/huggingface',
#  'https://www.linkedin.com/company/huggingface/',
#  '/join/discord']

# %%
get_links("https://huggingface.co")
# Out:
# {'links': [{'type': 'about page', 'url': 'https://huggingface.co/#/'},
#   {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'},
#   {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'},
#   {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'},
#   {'type': 'blog page', 'url': 'https://huggingface.co/blog'},
#   {'type': 'linkedin page',
#    'url': 'https://www.linkedin.com/company/huggingface/'},
#   {'type': 'github page', 'url': 'https://github.com/huggingface'},
#   {'type': 'twitter page', 'url': 'https://twitter.com/huggingface'},
#   {'type': 'community forum', 'url': 'https://discuss.huggingface.co'}]}

# %% [markdown]
# ## Second step: make the brochure!
#
# Assemble all the details into another prompt to GPT4-o

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
print(get_all_details("https://huggingface.co"))
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'company page', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'community page', 'url': 'https://discuss.huggingface.co'}]}
# Landing page:
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# NEW
# Get started with Inference in seconds 🚀
# Reachy Mini: The Open Robot for AI Builders
# Welcome Cohere on the Hub 🔥
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# zai-org/GLM-4.5
# Updated
# 2 days ago
# •
# 3.93k
# •
# 667
# Qwen/Qwen3-Coder-480B-A35B-Instruct
# Updated
# 6 days ago
# •
# 17.4k
# •
# 906
# tencent/HunyuanWorld-1
# Updated
# 2 days ago
# •
# 6.83k
# •
# 437
# bosonai/higgs-audio-v2-generation-3B-base
# Updated
# 1 day ago
# •
# 111k
# •
# 453
# Qwen/Qwen3-235B-A22B-Thinking-2507
# Updated
# 1 day ago
# •
# 4.08k
# •
# 232
# Browse 1M+ models
# Spaces
# Running
# 11.1k
# 11.1k
# DeepSite v2
# 🐳
# Generate any application with DeepSeek
# Running
# 232
# 232
# Multi-Style Video-to-Anime Generator
# 📊
# Transfer your videos with different AnimeStyles & havefun!
# Running
# on
# Zero
# 228
# 228
# Higgs Audio Demo
# 🎤
# Higgs Audio Demo
# Running
# 232
# 232
# Qwen3 Coder WebDev
# 🌍
# Generate web application code from descriptions
# Running
# on
# Zero
# MCP
# 1.16k
# 1.16k
# FLUX.1 Kontext
# ⚡
# Kontext image editing on FLUX[dev]
# Browse 400k+ applications
# Datasets
# fka/awesome-chatgpt-prompts
# Updated
# Jan 6
# •
# 32.7k
# •
# 8.5k
# NousResearch/Hermes-3-Dataset
# Updated
# 19 days ago
# •
# 6.28k
# •
# 262
# interstellarninja/hermes_reasoning_tool_use
# Updated
# 7 days ago
# •
# 1.27k
# •
# 71
# MegaScience/MegaScience
# Updated
# 6 days ago
# •
# 3.03k
# •
# 53
# microsoft/rStar-Coder
# Updated
# 10 days ago
# •
# 10.5k
# •
# 159
# Browse 250k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Team & Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 777 models
# •
# 3.7k followers
# AI at Meta
# Enterprise
# company
# •
# 2.2k models
# •
# 6.98k followers
# Amazon
# company
# •
# 20 models
# •
# 3.32k followers
# Google
# Enterprise
# company
# •
# 1.04k models
# •
# 22.2k followers
# Intel
# company
# •
# 233 models
# •
# 2.8k followers
# Microsoft
# company
# •
# 418 models
# •
# 13.9k followers
# Grammarly
# Team
# company
# •
# 10 models
# •
# 171 followers
# Writer
# Enterprise
# company
# •
# 21 models
# •
# 317 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 147,663
# State-of-the-art AI models for PyTorch
# Diffusers
# 29,998
# State-of-the-art Diffusion models in PyTorch
# Safetensors
# 3,369
# Safe way to store/distribute neural network weights
# Hub Python Library
# 2,801
# Python client to interact with the Hugging Face Hub
# Tokenizers
# 9,941
# Fast tokenizers optimized for research & production
# TRL
# 14,811
# Train transformers LMs with reinforcement learning
# Transformers.js
# 14,244
# State-of-the-art ML running directly in your browser
# smolagents
# 21,674
# Smol library to build great agents in Python
# PEFT
# 19,169
# Parameter-efficient finetuning for large language models
# Datasets
# 20,438
# Access & share datasets for any ML tasks
# Text Generation Inference
# 10,371
# Serve language models with TGI optimized toolkit
# Accelerate
# 8,981
# Train PyTorch models with multi-GPU, TPU, mixed precision
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# about page
# Webpage Title:
# huggingface (Hugging Face)
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Hugging Face
# Enterprise
# company
# Verified
# https://huggingface.co
# huggingface
# huggingface
# Activity Feed
# Follow
# 51,308
# AI & ML interests
# The AI community building the future.
# Recent Activity
# sayakpaul
# updated
# a dataset
# about 8 hours ago
# huggingface/diffusers-metadata
# muhammadsaeed1
# updated
# a dataset
# about 14 hours ago
# huggingface/documentation-images
# clem
# new
# activity
# about 16 hours ago
# huggingface/InferenceSupport:
# arcee-ai/AFM-4.5B
# View all activity
# Articles
# TimeScope: How Long Can Your Video Large Multimodal Model Go?
# 7 days ago
# •
# 29
# Yay! Organizations can now publish blog Articles
# Jan 20
# •
# 48
# Team members
# 211
# +177
# +164
# +143
# +133
# +113
# Organization Card
# Community
# About org cards
# 👋 Hi!
# We are on a mission to democratize
# good
# machine learning, one commit at a time.
# If that sounds like something you should be doing, why don't you
# join us
# !
# For press enquiries, you can
# ✉️ contact our team here
# .
# Collections
# 1
# DistilBERT release
# Original DistilBERT model, checkpoints obtained from using teacher-student learning from the original BERT checkpoints.
# distilbert/distilbert-base-cased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 142k
# •
# •
# 51
# distilbert/distilbert-base-uncased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 10.7M
# •
# •
# 733
# distilbert/distilbert-base-multilingual-cased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 805k
# •
# 203
# distilbert/distilbert-base-uncased-finetuned-sst-2-english
# Text Classification
# •
# 0.1B
# •
# Updated
# Dec 19, 2023
# •
# 3.08M
# •
# •
# 801
# DistilBERT release
# Original DistilBERT model, checkpoints obtained from using teacher-student learning from the original BERT checkpoints.
# distilbert/distilbert-base-cased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 142k
# •
# •
# 51
# distilbert/distilbert-base-uncased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 10.7M
# •
# •
# 733
# distilbert/distilbert-base-multilingual-cased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 805k
# •
# 203
# distilbert/distilbert-base-uncased-finetuned-sst-2-english
# Text Classification
# •
# 0.1B
# •
# Updated
# Dec 19, 2023
# •
# 3.08M
# •
# •
# 801
# spaces
# 29
# Sort:
# 		Recently updated
# pinned
# Running
# 15
# Enterprise Hub
# 🔒
# Why you need it, how to get it
# huggingface
# Jun 27
# pinned
# Running
# on
# CPU Upgrade
# 15
# Hugging Face Fast
# 🏎
# Test Hugging Face bandwidth
# huggingface
# Jun 12
# pinned
# Running
# 96
# Number Tokenization Blog
# 📈
# Explore how tokenization affects arithmetic in LLMs
# huggingface
# Dec 14, 2024
# Running
# on
# CPU Upgrade
# 191
# Inference Playground
# 🔋
# Set theme for Hugging Face Playground
# huggingface
# 9 days ago
# Running
# on
# CPU Upgrade
# 18
# Openapi
# 🦀
# Hub API Documentation
# huggingface
# Jun 18
# Running
# 449
# AI Deadlines
# ⚡
# Manage project deadlines efficiently
# huggingface
# Jun 8
# View 29
# 							Spaces
# models
# 16
# Sort:
# 		Recently updated
# huggingface/time-series-transformer-tourism-monthly
# Time Series Forecasting
# •
# 0.0B
# •
# Updated
# May 24
# •
# 3.38k
# •
# 22
# huggingface/timesfm-tourism-monthly
# 0.0B
# •
# Updated
# Mar 31
# •
# 18
# •
# 2
# huggingface/CodeBERTa-language-id
# Text Classification
# •
# Updated
# Mar 29, 2024
# •
# 1.03k
# •
# •
# 62
# huggingface/falcon-40b-gptq
# Text Generation
# •
# 7B
# •
# Updated
# Jun 14, 2023
# •
# 17
# •
# 12
# huggingface/autoformer-tourism-monthly
# Updated
# May 24, 2023
# •
# 2.6k
# •
# 10
# huggingface/distilbert-base-uncased-finetuned-mnli
# Text Classification
# •
# 0.1B
# •
# Updated
# Mar 22, 2023
# •
# 166
# •
# 2
# huggingface/informer-tourism-monthly
# Updated
# Feb 24, 2023
# •
# 2.42k
# •
# 6
# huggingface/the-no-branch-repo
# Text-to-Image
# •
# Updated
# Feb 10, 2023
# •
# 16
# •
# 5
# huggingface/CodeBERTa-small-v1
# Fill-Mask
# •
# Updated
# Jun 27, 2022
# •
# 54.1k
# •
# •
# 82
# huggingface/test-model-repo
# Updated
# Nov 19, 2021
# •
# 1
# View 16
# 							models
# datasets
# 34
# Sort:
# 		Recently updated
# huggingface/diffusers-metadata
# Viewer
# •
# Updated
# about 8 hours ago
# •
# 72
# •
# 544
# •
# 7
# huggingface/documentation-images
# Viewer
# •
# Updated
# about 14 hours ago
# •
# 55
# •
# 2.73M
# •
# 77
# huggingface/transformers-metadata
# Viewer
# •
# Updated
# 1 day ago
# •
# 1.79k
# •
# 1.14k
# •
# 26
# huggingface/policy-docs
# Viewer
# •
# Updated
# 11 days ago
# •
# 26
# •
# 2.48k
# •
# 13
# huggingface/badges
# Viewer
# •
# Updated
# 13 days ago
# •
# 1
# •
# 416k
# •
# 45
# huggingface/cats-image
# Viewer
# •
# Updated
# Jun 20
# •
# 1
# •
# 11.5k
# •
# 2
# huggingface/label-files
# Updated
# Jun 12
# •
# 2.19k
# •
# 19
# huggingface/electricity-production
# Viewer
# •
# Updated
# May 22
# •
# 397
# •
# 43
# •
# 1
# huggingface/gemini-results-new-cs-papers-2025-02-11-100-230-updated
# Viewer
# •
# Updated
# Feb 17
# •
# 130
# •
# 49
# huggingface/wiki_dpr
# Updated
# Feb 5
# •
# 85
# View 34
# 							datasets
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# careers page
# Webpage Title:
# Hugging Face - Current Openings
# Webpage Contents:
#
#
#
#
# blog page
# Webpage Title:
# Hugging Face – Blog
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Blog, Articles, and discussions
# New Article
# Everything
# community
# guide
# open source collab
# partnerships
# research
# NLP
# Audio
# CV
# RL
# ethics
# Diffusion
# Game Development
# RLHF
# Leaderboard
# Case Studies
# LeRobot
# Inference Providers
# Introducing Trackio: A Lightweight Experiment Tracking Library from Hugging Face
# By
# abidlabs
# July 29, 2025
# •
# 70
# Community Articles
# view all
# Unlocking Healthcare AI: I'm Releasing State-of-the-Art Medical Models for Free. Forever.
# By
# MaziyarPanahi
# •
# 14 days ago
# •
# 125
# LLMGameHub: How We Won the Gradio Agents & MCP Hackathon 2025
# By
# kikikita
# and 1 other
# •
# 2 days ago
# •
# 13
# How to Run a Hugging Face Model in JAX (Part 1)
# By
# qihqi
# •
# 10 days ago
# •
# 15
# Vibe coding for data science: how to label a dataset with Kimi K2
# By
# dvilasuero
# •
# 8 days ago
# •
# 19
# KV Caching Explained: Optimizing Transformer Inference Efficiency
# By
# not-lain
# •
# Jan 30
# •
# 104
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# Mar 17
# •
# 322
# AI Companionship: Why We Need to Evaluate How AI Systems Handle Emotional Bonds
# By
# giadap
# and 2 others
# •
# 9 days ago
# •
# 10
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 134
# OpenReasoning-Nemotron: A Family of State-of-the-Art Distilled Reasoning Models
# By
# nvidia
# and 3 others
# •
# 12 days ago
# •
# 47
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 195
# Introduction to State Space Models (SSM)
# By
# lbourdois
# •
# Jul 19, 2024
# •
# 153
# Prefill and Decode for Concurrent Requests - Optimizing LLM Performance
# By
# tngtech
# •
# Apr 16
# •
# 27
# Detecting Beyond Sight: Building AI-Enabled SAR Intelligence with Synthetic Data
# By
# DualityAI-RebekahBogdanoff
# •
# 5 days ago
# •
# 4
# We're open-sourcing "The Amazing Hand", a fully 3D printed robotic hand for less than $200  ✌️✌️✌️
# By
# pollen-robotics
# and 2 others
# •
# 22 days ago
# •
# 34
# Kimina-Prover: Applying Test-time RL Search on Large Formal Reasoning Models
# By
# AI-MO
# and 17 others
# •
# 20 days ago
# •
# 46
# Introducing ColQwen-Omni: Retrieve in every modality
# By
# manu
# and 4 others
# •
# 13 days ago
# •
# 58
# 🧠 MyMories `.mmr` – Compressed Memory Recall for LLM Continuity
# By
# B4S1C
# •
# 4 days ago
# •
# 3
# 🕺 Tensor Pose Animation Pipeline
# By
# B4S1C
# •
# 4 days ago
# •
# 3
# 🎭 Music Control Net for Video
# By
# B4S1C
# •
# 4 days ago
# •
# 3
# Fine-tune Llama 3 with ORPO
# By
# mlabonne
# •
# Apr 22, 2024
# •
# 239
# Say hello to `hf`: a faster, friendlier Hugging Face CLI ✨
# By
# Wauplin
# July 25, 2025
# •
# 54
# Parquet Content-Defined Chunking
# By
# kszucs
# July 25, 2025
# •
# 45
# TimeScope: How Long Can Your Video Large Multimodal Model Go?
# By
# orrzohar
# July 23, 2025
# •
# 29
# Fast LoRA inference for Flux with Diffusers and PEFT
# By
# sayakpaul
# July 23, 2025
# •
# 34
# Arc Virtual Cell Challenge: A Primer
# By
# FL33TW00D-HF
# July 18, 2025
# •
# 41
# Consilium: When Multiple LLMs Collaborate
# By
# azettl
# July 17, 2025
# guest
# •
# 17
# Back to The Future: Evaluating AI Agents on Predicting Future Events
# By
# vinid
# July 17, 2025
# guest
# •
# 27
# Five Big Improvements to Gradio MCP Servers
# By
# freddyaboulton
# July 17, 2025
# •
# 18
# Seq vs Seq: the Ettin Suite of Paired Encoders and Decoders
# By
# orionweller
# July 16, 2025
# •
# 50
# Migrating the Hub from Git LFS to Xet
# By
# jsulz
# July 15, 2025
# •
# 23
# Asynchronous Robot Inference: Decoupling Action Prediction and Execution
# By
# fracapuano
# July 10, 2025
# •
# 37
# ScreenEnv: Deploy your full stack Desktop Agent
# By
# A-Mahla
# July 10, 2025
# •
# 57
# Building the Hugging Face MCP Server
# By
# evalstate
# July 10, 2025
# •
# 52
# Reachy Mini - The Open-Source Robot for Today's and Tomorrow's AI Builders
# By
# thomwolf
# July 9, 2025
# •
# 615
# Previous
# 1
# 2
# 3
# ...
# 44
# Next
# Community Articles
# Sort:
# 		Trending
# Unlocking Healthcare AI: I'm Releasing State-of-the-Art Medical Models for Free. Forever.
# By
# MaziyarPanahi
# •
# 14 days ago
# •
# 125
# LLMGameHub: How We Won the Gradio Agents & MCP Hackathon 2025
# By
# kikikita
# and 1 other
# •
# 2 days ago
# •
# 13
# How to Run a Hugging Face Model in JAX (Part 1)
# By
# qihqi
# •
# 10 days ago
# •
# 15
# Vibe coding for data science: how to label a dataset with Kimi K2
# By
# dvilasuero
# •
# 8 days ago
# •
# 19
# KV Caching Explained: Optimizing Transformer Inference Efficiency
# By
# not-lain
# •
# Jan 30
# •
# 104
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# Mar 17
# •
# 322
# AI Companionship: Why We Need to Evaluate How AI Systems Handle Emotional Bonds
# By
# giadap
# and 2 others
# •
# 9 days ago
# •
# 10
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 134
# OpenReasoning-Nemotron: A Family of State-of-the-Art Distilled Reasoning Models
# By
# nvidia
# and 3 others
# •
# 12 days ago
# •
# 47
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 195
# Introduction to State Space Models (SSM)
# By
# lbourdois
# •
# Jul 19, 2024
# •
# 153
# Prefill and Decode for Concurrent Requests - Optimizing LLM Performance
# By
# tngtech
# •
# Apr 16
# •
# 27
# Detecting Beyond Sight: Building AI-Enabled SAR Intelligence with Synthetic Data
# By
# DualityAI-RebekahBogdanoff
# •
# 5 days ago
# •
# 4
# We're open-sourcing "The Amazing Hand", a fully 3D printed robotic hand for less than $200  ✌️✌️✌️
# By
# pollen-robotics
# and 2 others
# •
# 22 days ago
# •
# 34
# Kimina-Prover: Applying Test-time RL Search on Large Formal Reasoning Models
# By
# AI-MO
# and 17 others
# •
# 20 days ago
# •
# 46
# Introducing ColQwen-Omni: Retrieve in every modality
# By
# manu
# and 4 others
# •
# 13 days ago
# •
# 58
# 🧠 MyMories `.mmr` – Compressed Memory Recall for LLM Continuity
# By
# B4S1C
# •
# 4 days ago
# •
# 3
# 🕺 Tensor Pose Animation Pipeline
# By
# B4S1C
# •
# 4 days ago
# •
# 3
# 🎭 Music Control Net for Video
# By
# B4S1C
# •
# 4 days ago
# •
# 3
# Fine-tune Llama 3 with ORPO
# By
# mlabonne
# •
# Apr 22, 2024
# •
# 239
# View all
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# company page
# Webpage Title:
# Hugging Face | LinkedIn
# Webpage Contents:
# Skip to main content
# LinkedIn
# Top Content
# People
# Learning
# Jobs
# Games
# Get the app
# Join now
# Sign in
# Hugging Face
# Software Development
# The AI community building the future.
# See jobs
# Follow
# View all 591 employees
# Report this company
# About us
# The AI community building the future.
# Website
# https://huggingface.co
# External link for Hugging Face
# Industry
# Software Development
# Company size
# 51-200 employees
# Type
# Privately Held
# Founded
# 2016
# Specialties
# machine learning, natural language processing, and deep learning
# Products
# Hugging Face
# Hugging Face
# Natural Language Processing (NLP) Software
# We’re on a journey to solve and democratize artificial intelligence through natural language.
# Locations
# Primary
# Get directions
# Paris, FR
# Get directions
# Employees at Hugging Face
# Ludovic Huraux
# Rajat Arya
# Tech Lead & Software Engineer @ HF | prev: co-founder XetHub, Apple, Turi, AWS, Microsoft
# Jeff Boudier
# Product + Growth at Hugging Face
# Terrence Rohan
# Seed Investor
# See all employees
# Updates
# Hugging Face
# reposted this
# Alan Chhabra
# Executive Vice President, WW Partners @ Cerebras
# 14h
# Report this post
# Cerebras Systems
# is very proud to be offering Qwen3-235B 2507 with our strategic partner ,
# Hugging Face
# !
# https://lnkd.in/dDBcqHpc
# Thank you
# Clem Delangue 🤗
# Vaibhav Srivastav
# and
# Julien Chaumond
# for the partnership!
# Qwen/Qwen3-235B-A22B-Instruct-2507 · Hugging Face
# huggingface.co
# 99
# 8 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 67,885 followers
# 19h
# Report this post
# Don't use any ML tracking solution for your training runs before reading this!
# 🔥 Technical Report:
# https://lnkd.in/gqhguKbP
# …more
# 32
# 1 Comment
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 67,885 followers
# 20h
# Edited
# Report this post
# 😍 A multi-agent platform where users CREATE & PLAY AI-generated games with dynamic stories, visuals & music — built with
# Gradio
# ,
# LangChain
# 's
# LangGraph AI
# ,
# Google Gemini
# , Google Lyria, &
# Redis
# .
#
# Team won first place at the Gradio Agents & MCP Hackathon 2025!
# Published on
# Hugging Face
# Blog:
# https://lnkd.in/gWpV5k88
# 77
# 3 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Daniel van Strien
# Machine Learning Librarian at Hugging Face 🤗 | Making AI work for libraries, archives, and their communities
# 1d
# Report this post
# HF Jobs just launched - and here's how to get started in seconds! 🚀
#
# I extracted text from thousands of classified UFO documents with one command:
#
# ```
# hf jobs uv run --flavor l4x1 \
# https://lnkd.in/e3JyYPsD
# \
#  davanstrien/ufo-ColPali davanstrien/ufo-ocr
# ```
#
# From aged government documents with typewriter text, stamps, and handwriting → clean, searchable markdown. All powered by Nanonets-OCR-s, a state-of-the-art vision-language model that handles LaTeX, tables, forms, and complex layouts. Running on cloud GPUs with zero setup.
#
# This is the power of HF Jobs + uv Scripts:
# - No local GPU needed
# - No dependency management
# - Scripts are self-contained with inline metadata
# - Pay only for compute time used
#
# The uv Scripts organization (
# huggingface.co/uv-scripts
# ) is building a collection of ready-to-run ML tools:
# - VLM-based OCR for any documents
# - Text classification with structured outputs
# - PDF to dataset conversion
# - High-performance vLLM inference
#
# Each script works instantly - just `hf jobs uv run [script] [args]` and you're processing data on A100s.
#
# Big thanks to
# Charlie Marsh
# and the
# Astral
# team for building uv - this amazing tooling makes it all possible!
#
# What repetitive ML task would save you time if it were a one-command script? Drop a comment below - would love to hear what the community needs!
# 222
# 12 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Freddy Boulton
# Software Engineer @ 🤗
# 1d
# Report this post
# Serving LLMs? Turns out 𝐩𝐲𝐭𝐡𝐨𝐧 𝐢𝐬 𝐀𝐋𝐋 𝐲𝐨𝐮 𝐧𝐞𝐞𝐝!
# Hugging Face
# transformers now includes a built-in LLM inference server. Pair it with
# Gradio
# , and you can spin up a fully local, private chat UI with any LLM hosted on the Hugging Face Hub – all in just two lines of code!
# …more
# 650
# 16 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 67,885 followers
# 2d
# Edited
# Report this post
# 📢 Integrate your business backends into any MCP-compatible LLM!!
#
# 👉 👉 Transform OpenAPI Specs to MCP servers in One Line!
# Earlier: Manually map API endpoints to MCP tools. Time-consuming + error-prone.
# Now: Automated process with Gradio👇 Single line implementation!
#
# Key features:
# * Browse the UI and filter the endpoints that matter
# * Host your MCP server for free on
# Hugging Face
# * Complete No code solution 🤯
# …more
# 127
# 3 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 67,885 followers
# 5d
# Edited
# Report this post
# 📢WILD! You'll soon be able to build IMMERSIVE apps in Python🤯 stay tuned for more ..
# …more
# 89
# 2 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 67,885 followers
# 4d
# Report this post
# Vibe editor built into your local experience!🤩
#
# Coming soon, stay tuned fam!
# …more
# 113
# 7 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Lysandre Debut
# COSO - Chief Open Source Officer at Hugging Face
# 4d
# Edited
# Report this post
# The new transformers release comes w/ a surprise: kernels support ⚡️
#
# It integrates deeply with precompiled kernels on the HF Hub.
#
# - opt-in, automatic kernels for your hardware and software
# - kernels like FA2/3 w/o compilation
# - community-built kernels, for inference & training
#
# This is not simply a speed-up, but also a memory reduction: run bigger models, faster.
#
# We're working with kernel providers like
# Unsloth AI
# ,
# Red Hat
# ,
# vLLM
# ,
# ggml
# and others so that kernels they build are reused across runtimes, from their Hub org.
# 220
# 10 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Brigitte Tousignant
# Comms 🤗
# 4d
# Report this post
# It’s not about the race for the frontier but the race for the global AI ecosystem, which can only be achieved by developing more open-source and open-weight models to deploy locally.
# Hugging Face
# Chief Policy Officer
# Irene Solaiman
# joined Ed Ludlow &
# Caroline Hyde
# on
# Bloomberg News
# to discuss our key takeaways from the U.S. AI Action Plan.
# …more
# 69
# 4 Comments
# Like
# Comment
# Share
# Join now to see what you are missing
# Find people you know at Hugging Face
# Browse recommended jobs for you
# View all updates, news, and articles
# Join now
# Similar pages
# Anthropic
# Research Services
# Perplexity
# Software Development
# San Francisco, California
# Mistral AI
# Technology, Information and Internet
# Paris, France
# OpenAI
# Research Services
# San Francisco, CA
# LangChain
# Technology, Information and Internet
# Generative AI
# Technology, Information and Internet
# Google DeepMind
# Research Services
# London, London
# DeepLearning.AI
# Software Development
# Palo Alto, California
# Cohere
# Software Development
# Toronto, Ontario
# LlamaIndex
# Technology, Information and Internet
# San Francisco, California
# Show more similar pages
# Show fewer similar pages
# Browse jobs
# Engineer jobs
# 555,845 open jobs
# Machine Learning Engineer jobs
# 148,937 open jobs
# Scientist jobs
# 48,969 open jobs
# Software Engineer jobs
# 300,699 open jobs
# Analyst jobs
# 694,057 open jobs
# Intern jobs
# 71,196 open jobs
# Developer jobs
# 258,935 open jobs
# Manager jobs
# 1,880,925 open jobs
# Product Manager jobs
# 199,941 open jobs
# Director jobs
# 1,220,357 open jobs
# Python Developer jobs
# 46,642 open jobs
# Data Scientist jobs
# 264,158 open jobs
# Data Analyst jobs
# 329,009 open jobs
# Senior Software Engineer jobs
# 78,145 open jobs
# Project Manager jobs
# 253,048 open jobs
# Researcher jobs
# 195,654 open jobs
# Associate jobs
# 1,091,945 open jobs
# Data Engineer jobs
# 192,126 open jobs
# Vice President jobs
# 235,270 open jobs
# Specialist jobs
# 768,666 open jobs
# Show more jobs like this
# Show fewer jobs like this
# Funding
# Hugging Face
# 8 total rounds
# Last Round
# Series unknown
# Sep 1, 2024
# External Crunchbase Link for last round of funding
# See more info on
# crunchbase
# More searches
# More searches
# Engineer jobs
# Scientist jobs
# Machine Learning Engineer jobs
# Software Engineer jobs
# Intern jobs
# Developer jobs
# Analyst jobs
# Manager jobs
# Senior Software Engineer jobs
# Data Scientist jobs
# Researcher jobs
# Product Manager jobs
# Director jobs
# Associate jobs
# Intelligence Specialist jobs
# Data Analyst jobs
# Data Science Specialist jobs
# Python Developer jobs
# Quantitative Analyst jobs
# Project Manager jobs
# Account Executive jobs
# Specialist jobs
# Data Engineer jobs
# Designer jobs
# Quantitative Researcher jobs
# Consultant jobs
# Solutions Architect jobs
# Vice President jobs
# User Experience Designer jobs
# Head jobs
# Full Stack Engineer jobs
# Engineering Manager jobs
# Software Engineer Intern jobs
# Junior Software Engineer jobs
# Software Intern jobs
# Product Designer jobs
# Solutions Engineer jobs
# Staff Software Engineer jobs
# Program Manager jobs
# Senior Scientist jobs
# Writer jobs
# Research Intern jobs
# Senior Product Manager jobs
# Summer Intern jobs
# Account Manager jobs
# Recruiter jobs
# Lead jobs
# Research Engineer jobs
# Computer Science Intern jobs
# Platform Engineer jobs
# Junior Developer jobs
# Android Developer jobs
# User Experience Researcher jobs
# Java Software Engineer jobs
# Site Reliability Engineer jobs
# Graduate jobs
# Software Engineering Manager jobs
# Representative jobs
# Business Development Specialist jobs
# Computer Engineer jobs
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# العربية (Arabic)
# বাংলা (Bangla)
# Čeština (Czech)
# Dansk (Danish)
# Deutsch (German)
# Ελληνικά (Greek)
# English (English)
# Español (Spanish)
# فارسی (Persian)
# Suomi (Finnish)
# Français (French)
# हिंदी (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# עברית (Hebrew)
# 日本語 (Japanese)
# 한국어 (Korean)
# मराठी (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ਪੰਜਾਬੀ (Punjabi)
# Polski (Polish)
# Português (Portuguese)
# Română (Romanian)
# Русский (Russian)
# Svenska (Swedish)
# తెలుగు (Telugu)
# ภาษาไทย (Thai)
# Tagalog (Tagalog)
# Türkçe (Turkish)
# Українська (Ukrainian)
# Tiếng Việt (Vietnamese)
# 简体中文 (Chinese (Simplified))
# 正體中文 (Chinese (Traditional))
# Language
# Agree & Join LinkedIn
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Sign in to see who you already know at Hugging Face
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# LinkedIn
# LinkedIn is better on the app
# Don’t have the app? Get it in the Microsoft Store.
# Open the app
#
#
#
# community page
# Webpage Title:
# Hugging Face Forums - Hugging Face Community Discussion
# Webpage Contents:
# Hugging Face Forums
# Topic
# Replies
# Views
# Activity
# Rate limited with Pro subscription
# Beginners
# 1
# 15
# July 30, 2025
# Error while initializing ZeroGPU
# Models
# 10
# 116
# July 30, 2025
# On restart ZeroGPU not working but on CPU it works
# Spaces
# 2
# 18
# July 30, 2025
# My Experience: Postman vs Hoppscotch vs Apidog
# Beginners
# 3
# 14
# July 29, 2025
# Spaces not working after restart
# Spaces
# 5
# 15
# July 29, 2025
# RT-DETRV2 and normalization
# 🤗Transformers
# 2
# 18
# July 30, 2025
# One Tool That Boosted My API Productivity
# Beginners
# 0
# 19
# July 29, 2025
# Using transformers on Kaggle
# 🤗Transformers
# 1
# 4
# July 29, 2025
# Looking for Starter-Model Tips: What’s Your Go-To Baseline for the “DeFi-Behavior” Demo?
# Models
# 0
# 7
# July 29, 2025
# N8n on Hugging Face Space: getaddrinfo ENOTFOUND api.telegram.org Connection Error
# Spaces
# 16
# 253
# July 25, 2025
# 📢 New Demo Dataset: “DeFi-Behavior 0728” – real on-chain trading episodes, already labeled
# 🤗Datasets
# 0
# 7
# July 29, 2025
# API Access Disabled?
# 🤗Hub
# 1
# 8
# July 29, 2025
# Why does RAG still feel clunky in 2025?
# Intermediate
# 6
# 76
# July 29, 2025
# Persistent 404 Not Found Errors with Public Inference API
# Inference Endpoints on the Hub
# 11
# 1321
# July 29, 2025
# Potential bug in the rt-detr v2 fine tune script
# 🤗Transformers
# 5
# 276
# July 29, 2025
# Suggestion: Import papers outside arXiv
# Awesome paper
# 1
# 16
# July 29, 2025
# Problem in Agents Course
# Beginners
# 10
# 146
# July 29, 2025
# How to fine tune a base model?
# Beginners
# 1
# 22
# July 29, 2025
# Fine tuning and it's effects on model safety
# Models
# 7
# 58
# July 28, 2025
# Model responses are random ignoring my dataset
# 🤗AutoTrain
# 12
# 21
# July 28, 2025
# Should agent payments be a separate system from human payments?
# Research
# 1
# 19
# July 28, 2025
# Designing a Backend System where Code is Natural Language in gemini.md
# Research
# 1
# 16
# July 29, 2025
# Interest in a Real DeFi Trading Dataset with Microstructure Details?
# 🤗Datasets
# 4
# 13
# July 29, 2025
# Open-Source Multilingual Knowledge Signal Generator – PROTOCORE (Feedback Welcome!)
# 🤗Datasets
# 0
# 2
# July 29, 2025
# Space Stuck At "Running" – Nothing Works / Cant Access Paid Storage / Who to Contact?
# Beginners
# 7
# 28
# July 28, 2025
# CAS service error when downloading gated models on Databricks even with HF_HUB_DISABLE_XET=1
# Models
# 7
# 37
# July 30, 2025
# Paper authorship got denied
# Beginners
# 0
# 11
# July 29, 2025
# Gradient Issue after using torch.no_grad
# 🧨 Diffusers
# 1
# 12
# July 27, 2025
# Creating A Team Of LLMs
# Intermediate
# 5
# 267
# July 30, 2025
# I am getting this error only Inference Providers with accurate pricing are available for organizations
# Beginners
# 12
# 66
# July 29, 2025
# next page →
# Home
# Categories
# Guidelines
# Terms of Service
# Privacy Policy
# Powered by
# Discourse
# , best viewed with JavaScript enabled

# %%
system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

# system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
# and creates a short humorous, entertaining, jokey brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
# Include details of company culture, customers and careers/jobs if you have the information."

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:5_000] # Truncate if more than 5,000 characters
    return user_prompt

# %%
get_brochure_user_prompt("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'blog', 'url': 'https://huggingface.co/blog'}, {'type': 'company page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'models page', 'url': 'https://huggingface.co/models'}, {'type': 'datasets page', 'url': 'https://huggingface.co/datasets'}, {'type': 'spaces page', 'url': 'https://huggingface.co/spaces'}, {'type': 'documentation page', 'url': 'https://huggingface.co/docs'}]}
# 'You are looking at a company called: HuggingFace\nHere are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\nLanding page:\nWebpage Title:\nHugging Face – The AI community building the future.\nWebpage Contents:\nHugging Face\nModels\nDatasets\nSpaces\nCommunity\nDocs\nEnterprise\nPricing\nLog In\nSign Up\nNEW\nGet started with Inference in seconds 🚀\nReachy Mini: The Open Robot for AI Builders\nWelcome Cohere on the Hub 🔥\nThe AI community building the future.\nThe platform where the machine learning community collaborates on models, datasets, and applications.\nExplore AI Apps\nor\nBrowse 1M+ models\nTrending on\nthis week\nModels\nzai-org/GLM-4.5\nUpdated\n2 days ago\n•\n3.93k\n•\n668\nQwen/Qwen3-Coder-480B-A35B-Instruct\nUpdated\n6 days ago\n•\n17.4k\n•\n906\ntencent/HunyuanWorld-1\nUpdated\n2 days ago\n•\n6.83k\n•\n437\nbosonai/higgs-audio-v2-generation-3B-base\nUpdated\n1 day ago\n•\n111k\n•\n453\nQwen/Qwen3-235B-A22B-Thinking-2507\nUpdated\n1 day ago\n•\n4.08k\n•\n232\nBrowse 1M+ models\nSpaces\nRunning\n11.1k\n11.1k\nDeepSite v2\n🐳\nGenerate any application with DeepSeek\nRunning\n232\n232\nMulti-Style Video-to-Anime Generator\n📊\nTransfer your videos with different AnimeStyles & havefun!\nRunning\non\nZero\n228\n228\nHiggs Audio Demo\n🎤\nHiggs Audio Demo\nRunning\n233\n233\nQwen3 Coder WebDev\n🌍\nGenerate web application code from descriptions\nRunning\non\nZero\nMCP\n1.16k\n1.16k\nFLUX.1 Kontext\n⚡\nKontext image editing on FLUX[dev]\nBrowse 400k+ applications\nDatasets\nfka/awesome-chatgpt-prompts\nUpdated\nJan 6\n•\n32.7k\n•\n8.5k\nNousResearch/Hermes-3-Dataset\nUpdated\n19 days ago\n•\n6.28k\n•\n262\ninterstellarninja/hermes_reasoning_tool_use\nUpdated\n7 days ago\n•\n1.27k\n•\n71\nMegaScience/MegaScience\nUpdated\n6 days ago\n•\n3.03k\n•\n53\nmicrosoft/rStar-Coder\nUpdated\n10 days ago\n•\n10.5k\n•\n159\nBrowse 250k+ datasets\nThe Home of Machine Learning\nCreate, discover and collaborate on ML better.\nThe collaboration platform\nHost and collaborate on unlimited public models, datasets and applications.\nMove faster\nWith the HF Open source stack.\nExplore all modalities\nText, image, video, audio or even 3D.\nBuild your portfolio\nShare your work with the world and build your ML profile.\nSign Up\nAccelerate your ML\nWe provide paid Compute and Enterprise solutions.\nCompute\nDeploy on optimized\nInference Endpoints\nor update your\nSpaces applications\nto a GPU in a few clicks.\nView pricing\nStarting at $0.60/hour for GPU\nTeam & Enterprise\nGive your team the most advanced platform to build AI with enterprise-grade security, access controls and\n\t\t\tdedicated support.\nGetting started\nStarting at $20/user/month\nSingle Sign-On\nRegions\nPriority Support\nAudit Logs\nResource Groups\nPrivate Datasets Viewer\nMore than 50,000 organizations are using Hugging Face\nAi2\nEnterprise\nnon-profit\n•\n777 models\n•\n3.7k followers\nAI at Meta\nEnterprise\ncompany\n•\n2.2k models\n•\n6.98k followers\nAmazon\ncompany\n•\n20 models\n•\n3.32k followers\nGoogle\nEnterprise\ncompany\n•\n1.04k models\n•\n22.2k followers\nIntel\ncompany\n•\n233 models\n•\n2.8k followers\nMicrosoft\ncompany\n•\n418 models\n•\n13.9k followers\nGrammarly\nTeam\ncompany\n•\n10 models\n•\n171 followers\nWriter\nEnterprise\ncompany\n•\n21 models\n•\n317 followers\nOur Open Source\nWe are building the foundation of ML tooling with the community.\nTransformers\n147,663\nState-of-the-art AI models for PyTorch\nDiffusers\n29,998\nState-of-the-art Diffusion models in PyTorch\nSafetensors\n3,369\nSafe way to store/distribute neural network weights\nHub Python Library\n2,801\nPython client to interact with the Hugging Face Hub\nTokenizers\n9,941\nFast tokenizers optimized for research & production\nTRL\n14,811\nTrain transformers LMs with reinforcement learning\nTransformers.js\n14,244\nState-of-the-art ML running directly in your browser\nsmolagents\n21,674\nSmol l ...

# %%
def create_brochure(company_name, url):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

# %%
create_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/about'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'documentation page', 'url': 'https://huggingface.co/docs'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'community forum', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# # Hugging Face Brochure
#
# ## About Us
# Hugging Face is the leading AI community dedicated to building the future of machine learning. Our platform serves as an interactive hub where developers, researchers, and industry leaders collaborate on models, datasets, and applications. We aim to empower the AI community by providing a state-of-the-art environment for learning, sharing, and deploying AI solutions.
#
# ## Culture
# At Hugging Face, we foster a culture of collaboration, openness, and innovation. We believe in the power of community and are committed to creating an inclusive environment where everyone can contribute and grow. Our open-source spirit encourages sharing and promoting knowledge, allowing teams to move faster and create impactful AI solutions together.
#
# ## Our Services
# ### Models
# - Explore over **1 million models** on our platform, ranging from natural language processing to image recognition and beyond.
# - Access trending models such as **GLM-4.5** and **HunyuanWorld-1**, continuously updated to reflect the latest advancements.
#
# ### Datasets
# - Browse an extensive library of **250,000+ datasets**, enabling users to find the right data for their AI projects.
#
# ### Spaces
# - Develop and run applications through **11,000+ interactive Spaces**, facilitating creativity and showcasing innovative use cases in real-time.
#
# ### Enterprise Solutions
# - Hugging Face provides enterprise-grade solutions, including:
#   - Customizable Compute and Inference Endpoints
#   - Security features, access controls, and priority support for organizations.
#
# ## Who We Serve
# Our platform is trusted by over **50,000 organizations**, including major enterprises like **Google**, **Microsoft**, and **Amazon**. These collaborations highlight our commitment to quality and innovation in the AI landscape.
#
# ## Careers
# Join our mission to shape the future of AI! We are actively looking for passionate individuals to expand our talented team. Whether you're in engineering, research, or support roles, Hugging Face offers exciting opportunities for career growth in a dynamic and supportive environment.
#
# ### Current Openings
# - Visit our [Careers Page](#) to explore open positions and learn more about the benefits of joining the Hugging Face team.
#
# ## Get Started
# Ready to transform your AI projects? Sign up now to access our models, datasets, and collaborative tools.
#
# **Connect With Us**
# - [GitHub](#) | [Twitter](#) | [LinkedIn](#) | [Discord](#)
#
# ---
#
# Hugging Face: **The AI community building the future.**

# %% [markdown]
# ## Finally - a minor improvement
#
# With a small adjustment, we can change this so that the results stream back from OpenAI,
# with the familiar typewriter animation

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
        stream=True
    )
    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'company page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# # Hugging Face Company Brochure
#
# ---
#
# ## Welcome to Hugging Face
#
# Hugging Face is at the forefront of the artificial intelligence revolution, serving as a vibrant community and collaborative platform focused on building the future of machine learning. With over **50,000 organizations** leveraging our tools, we empower developers, researchers, and enterprises to create, discover, and share machine learning models, datasets, and applications.
#
# ---
#
# ## Our Platform
#
# - **Models**: Explore over **1 million models**, including the latest updates from leading contributors in AI and ML.
# - **Datasets**: Access a wide range of datasets, exceeding **250,000**, suited for any ML tasks.
# - **Spaces**: Build and run applications quickly with our application hosting capabilities.
#
# **New Featured Tools**:
# - **Inference in Seconds**: Start deploying models seamlessly.
# - **Reachy Mini**: An open robot designed for AI innovators.
#
# ---
#
# ## Who We Serve
#
# Hugging Face caters to a diverse clientele:
# - Companies like **Google**, **Microsoft**, **Amazon**, and **Meta** utilize our platform for their machine learning projects.
# - Non-profit organizations and individuals leverage our open-source models and datasets to foster innovation and research.
#
# More than **50,000 organizations** are part of the Hugging Face family, fostering an ecosystem of creativity and collaboration.
#
# ---
#
# ## Company Culture
#
# At Hugging Face, we embody a community-centric approach:
# - **Open Source Philosophy**: We believe in building the future of ML collaboratively. Our vast library includes state-of-the-art tools like Transformers, Diffusers, and Tokenizers, all open for public contribution.
# - **Innovation and Collaboration**: We foster a stimulating environment where ideas flourish and teams collaborate to solve complex problems in AI & ML.
#
# ---
#
# ## Careers at Hugging Face
#
# Join us in shaping the future of AI!
# - We offer a variety of roles in engineering, research, marketing, and support.
# - Embrace an inclusive and flexible work culture that encourages continuous learning and growth.
#
# **Explore our career opportunities**: [Jobs Page](https://huggingface.co/jobs).
#
# ---
#
# ### Connect with Us
#
# - **Website**: [huggingface.co](https://huggingface.co)
# - **Community**: Join our community on [GitHub](https://github.com/huggingface), [Twitter](https://twitter.com/huggingface), [LinkedIn](https://www.linkedin.com/company/huggingface), and [Discord](https://discord.com/invite/huggingface).
#
# Together, let's build the future of artificial intelligence! 🚀

# %%
# Try changing the system prompt to the humorous version when you make the Brochure for Hugging Face:

stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'blog', 'url': 'https://huggingface.co/blog'}, {'type': 'documentation', 'url': 'https://huggingface.co/docs'}, {'type': 'GitHub', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter', 'url': 'https://twitter.com/huggingface'}, {'type': 'LinkedIn', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# # Hugging Face Brochure
#
# ## About Us
# Welcome to **Hugging Face**, the AI community building the future. We are a collaborative platform at the forefront of machine learning, dedicated to creating, discovering, and sharing AI models, datasets, and applications. Our mission is to empower individuals and organizations to harness the potential of machine learning, making it accessible for various creative and practical uses.
#
# ## Our Offerings
# - **Models**: Explore a diverse range of over **1 million** machine learning models, including the latest innovations tailored for various applications.
# - **Datasets**: Collaborate and access an extensive library of **250,000+ datasets** to support your machine learning projects.
# - **Spaces**: Create and host AI applications with ease, leveraging our platform to launch fun and functional tools.
# - **Documentation and Community Support**: We provide comprehensive documentation and an engaged community to help you along your journey in machine learning.
#
# ## Who We Serve
# Hugging Face is trusted by **more than 50,000 organizations** worldwide, including prominent companies such as Google, Microsoft, Amazon, Meta, and many more. Our platform supports a diverse range of users from **enterprise teams** seeking robust, security-minded solutions to **individual developers** looking to experiment and showcase their work.
#
# ## Join Us
# ### Careers
# We are continuously growing and are on the lookout for passionate individuals to join our team. At Hugging Face, you will have the opportunity to work with cutting-edge technologies in a vibrant, collaborative, and supportive environment. Come help us build a more intelligent future.
#
# **Current Openings**: Explore various career opportunities on our [jobs page](https://huggingface.co/jobs).
#
# ### Company Culture
# Hugging Face prides itself on fostering a culture of inclusivity, collaboration, and innovation. We value diversity of thought and background, and our team operates on principles of transparency and trust. We encourage all our members to share their ideas and contribute to our mission of democratizing AI.
#
# ## Engage with Us
# Stay updated with the latest advancements in artificial intelligence and machine learning. Follow us on our social media channels:
# - [GitHub](https://github.com/huggingface)
# - [Twitter](https://twitter.com/huggingface)
# - [LinkedIn](https://linkedin.com/company/huggingface)
# - [Discord](https://discord.gg/huggingface)
#
# Join our community and explore the possibilities of AI together!
#
# For more information, visit our official website: [Hugging Face](https://huggingface.co).
#
# ---
#
# *Transforming the way we interact with technology, one model at a time.*

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise we extended the Day 1 code to make multiple LLM calls, and generate a document.
#
# This is perhaps the first example of Agentic AI design patterns, as we combined multiple calls to LLMs. This will feature more in Week 2, and then we will return to Agentic AI in a big way in Week 8 when we build a fully autonomous Agent solution.
#
# Generating content in this way is one of the very most common Use Cases. As with summarization, this can be applied to any business vertical. Write marketing content, generate a product tutorial from a spec, create personalized email content, and so much more. Explore how you can apply content generation to your business, and try making yourself a proof-of-concept prototype. See what other students have done in the community-contributions folder -- so many valuable projects -- it's wild!</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you move to Week 2 (which is tons of fun)</h2>
#             <span style="color:#900;">Please see the week1 EXERCISE notebook for your challenge for the end of week 1. This will give you some essential practice working with Frontier APIs, and prepare you well for Week 2.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">A reminder on 3 useful resources</h2>
#             <span style="color:#f71;">1. The resources for the course are available <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">here.</a><br/>
#             2. I'm on LinkedIn <a href="https://www.linkedin.com/in/eddonner/">here</a> and I love connecting with people taking the course!<br/>
#             3. I'm trying out X/Twitter and I'm at <a href="https://x.com/edwarddonner">@edwarddonner<a> and hoping people will teach me how it's done..
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">Finally! I have a special request for you</h2>
#             <span style="color:#090;">
#                 My editor tells me that it makes a MASSIVE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. If you're able to take a minute to rate this, I'd be so very grateful! And regardless - always please reach out to me at ed@edwarddonner.com if I can help at any point.
#             </span>
#         </td>
#     </tr>
# </table>
